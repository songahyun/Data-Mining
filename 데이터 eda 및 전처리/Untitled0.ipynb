# %%
# !pip install workalendar

from workalendar.asia import SouthKorea
import os
import numpy as np
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# 2019년부터 2023년까지 공휴일 데이터를 가져오기

years = list(range(2021, 2024))

# SouthKorea 클래스 인스턴스 생성
cal = SouthKorea()

all_holidays = []

# 각 연도의 공휴일 정보 가져오기
for year in years:
    holiday_list = cal.holidays(year)
    all_holidays.extend(holiday_list)

# 공휴일 정보를 DataFrame으로 변환
holiday_df = pd.DataFrame(all_holidays, columns=['날짜', '공휴일'])

holiday_df
# Out:
# Requirement already satisfied: workalendar in /usr/local/lib/python3.10/dist-packages (17.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from workalendar) (2.8.2)
# Requirement already satisfied: lunardate in /usr/local/lib/python3.10/dist-packages (from workalendar) (0.2.2)
# Requirement already satisfied: convertdate in /usr/local/lib/python3.10/dist-packages (from workalendar) (2.4.0)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.10/dist-packages (from workalendar) (2.2.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.10/dist-packages (from convertdate->workalendar) (0.5.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->workalendar) (1.16.0)
#             날짜                      공휴일
# 0   2021-01-01                 New year
# 1   2021-02-11    Korean New Year's Day
# 2   2021-02-12    Korean New Year's Day
# 3   2021-02-13    Korean New Year's Day
# 4   2021-03-01         Independence Day
# 5   2021-05-05           Children's Day
# 6   2021-05-19        Buddha's Birthday
# 7   2021-06-06             Memorial Day
# 8   2021-08-15           Liberation Day
# 9   2021-09-20       Midautumn Festival
# 10  2021-09-21       Midautumn Festival
# 11  2021-09-22       Midautumn Festival
# 12  2021-10-03  National Foundation Day
# 13  2021-10-09               Hangul Day
# 14  2021-12-25            Christmas Day
# 15  2022-01-01                 New year
# 16  2022-01-31    Korean New Year's Day
# 17  2022-02-01    Korean New Year's Day
# 18  2022-02-02    Korean New Year's Day
# 19  2022-03-01         Independence Day
# 20  2022-05-05           Children's Day
# 21  2022-05-08        Buddha's Birthday
# 22  2022-06-06             Memorial Day
# 23  2022-08-15           Liberation Day
# 24  2022-09-09       Midautumn Festival
# 25  2022-09-10       Midautumn Festival
# 26  2022-09-11       Midautumn Festival
# 27  2022-10-03  National Foundation Day
# 28  2022-10-09               Hangul Day
# 29  2022-12-25            Christmas Day
# 30  2023-01-01                 New year
# 31  2023-01-21    Korean New Year's Day
# 32  2023-01-22    Korean New Year's Day
# 33  2023-01-23    Korean New Year's Day
# 34  2023-03-01         Independence Day
# 35  2023-05-05           Children's Day
# 36  2023-05-26        Buddha's Birthday
# 37  2023-06-06             Memorial Day
# 38  2023-08-15           Liberation Day
# 39  2023-09-28       Midautumn Festival
# 40  2023-09-29       Midautumn Festival
# 41  2023-09-30       Midautumn Festival
# 42  2023-10-03  National Foundation Day
# 43  2023-10-09               Hangul Day
# 44  2023-12-25            Christmas Day
